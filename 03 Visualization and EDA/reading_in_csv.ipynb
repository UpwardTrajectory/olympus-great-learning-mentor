# %%
from pathlib import Path

p = Path().home() / 'projects'

file_loc = p.rglob("*.csv")

[x for x in file_loc]
# Out:
# [WindowsPath("C:/Users/dakas/projects/great_learning/00 Beginner Session/DSBA Jul'21A _ Group J _ David.xlsx - Sheet1.csv"),
#  WindowsPath("C:/Users/dakas/projects/great_learning/00 Beginner Session/.ipynb_checkpoints/DSBA Jul'21A _ Group J _ David.xlsx - Sheet1-checkpoint.csv"),
#  WindowsPath('C:/Users/dakas/projects/great_learning/01 Introduction to Python/iris.csv'),
#  WindowsPath('C:/Users/dakas/projects/great_learning/01 Introduction to Python/.ipynb_checkpoints/iris-checkpoint.csv'),
#  WindowsPath('C:/Users/dakas/projects/great_learning/02 NumPy and Pandas/movie.csv'),
#  WindowsPath('C:/Users/dakas/projects/great_learning/02 NumPy and Pandas/ratings.csv'),
#  WindowsPath('C:/Users/dakas/projects/great_learning/02 NumPy and Pandas/user.csv'),
#  WindowsPath('C:/Users/dakas/projects/great_learning/02 NumPy and Pandas/.ipynb_checkpoints/movie-checkpoint.csv'),
# ...

# %%
import pandas as pd

df = pd.read_csv("C:/Users/dakas/projects/great_learning/00 Beginner Session/.ipynb_checkpoints/DSBA Jul'21A _ Group J _ David.xlsx - Sheet1-checkpoint.csv")
df.head()
# Out:
#   Group Candidate Name        Country  Country Code   Mobile No  \
# 0     J  Usman Tanveer  United States             1  3219462227
# 1     J     Ramon Ruiz  United States             1  3463258695
# 2     J  Chelscie Irby  United States             1  3462354944
# 3     J  David Manzano  United States             1  8327150390
# 4     J   ALICIA GREEN  United States             1  7136794389
#
#                       Email ID                         Company  \
# 0         usmantan87@gmail.com                        7-Eleven
# 1        reliasruiz7@gmail.com                           PDVSA
# 2       irbychelscie@gmail.com  A1 Personnel Staffing Agency\n
# 3           landalft@gmail.com                    Schlumberger
# 4  alicianicolegreen@gmail.com                 City of Houston
#
#                    Industry                  Designation  \
# 0                    Retail                Store Manager
# 1                    Energy  Senior Reservoir Engineer\n
# ...
